# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is EC5F-E8ED
#
#  Directory of D:\placements\sample_paleru\voice testing
#
# 08/03/2020  03:54 PM    <DIR>          .
# 08/03/2020  03:54 PM    <DIR>          ..
# 08/03/2020  03:54 PM    <DIR>          .ipynb_checkpoints
# 08/03/2020  03:52 PM        15,035,420 FD (1).wav
# 08/03/2020  03:52 PM        15,035,420 FD.wav
# 08/03/2020  03:52 PM        11,894,128 IU.wav
# 08/03/2020  03:54 PM                72 Untitled.ipynb
# 08/03/2020  03:52 PM        11,266,864 YU.wav
#                5 File(s)     53,231,904 bytes
#                3 Dir(s)  211,294,187,520 bytes free

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
f = 'YU.wav'
y, sr = librosa.load(f)
plt.figure(figsize=(10,5))
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
librosa.display.specshow(D, y_axis='linear')
plt.title(f)
# Out:
# Text(0.5, 1.0, 'YU.wav')

# %%
plt.figure(figsize=(13,8))


f = 'YU.wav'
y, sr = librosa.load(f)
plt.subplot(2,2,1)
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
librosa.display.specshow(D, y_axis='linear')
plt.title(f)


f = 'FD.wav'
y, sr = librosa.load(f)
plt.subplot(2,2,2)
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
librosa.display.specshow(D, y_axis='linear')
plt.title(f)

f = 'FD (1).wav'
y, sr = librosa.load(f)
plt.subplot(2,2,3)
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
librosa.display.specshow(D, y_axis='linear')
plt.title(f)

f = 'IU.wav'
y, sr = librosa.load(f)
plt.subplot(2,2,4)
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
librosa.display.specshow(D, y_axis='linear')
plt.title(f)
# Out:
# Text(0.5, 1.0, 'IU.wav')

# %%
f = 'FD (1).wav'
y, sr = librosa.load(f)
plt.figure(figsize=(10,5))
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
librosa.display.specshow(D, y_axis='linear')
plt.title(f)
# Out:
# Text(0.5, 1.0, 'FD (1).wav')

# %%
f = 'FD.wav'
y, sr = librosa.load(f)
plt.figure(figsize=(10,5))
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
librosa.display.specshow(D, y_axis='linear')
plt.title(f)
# Out:
# Text(0.5, 1.0, 'FD.wav')

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is EC5F-E8ED
#
#  Directory of D:\placements\sample_paleru\voice testing
#
# 08/03/2020  03:58 PM    <DIR>          .
# 08/03/2020  03:58 PM    <DIR>          ..
# 08/03/2020  03:54 PM    <DIR>          .ipynb_checkpoints
# 08/03/2020  03:52 PM        15,035,420 FD (1).wav
# 08/03/2020  03:52 PM        15,035,420 FD.wav
# 08/03/2020  03:52 PM        11,894,128 IU.wav
# 08/03/2020  03:58 PM         1,085,357 Untitled.ipynb
# 08/03/2020  03:52 PM        11,266,864 YU.wav
#                5 File(s)     54,317,189 bytes
#                3 Dir(s)  211,293,097,984 bytes free

# %%
import scipy.io.wavfile as wavfile
import numpy
import os.path
def signaltonoise(a, axis=0, ddof=0):
    a = np.asanyarray(a)
    m = a.mean(axis)
    sd = a.std(axis=axis, ddof=ddof)
    return np.where(sd == 0, 0, m/sd)

def snr(file):
  if (os.path.isfile(file)):
    data = wavfile.read(file)[1]
    singleChannel = data
    try:
      singleChannel = numpy.sum(data, axis=1)
    except:
      # was mono after all
      pass
      
    norm = singleChannel / (max(numpy.amax(singleChannel), -1 * numpy.amin(singleChannel)))
    print(f'signal to noise ratios for the file {file} is {signaltonoise(norm)}')
#     return stats.signaltonoise(norm)

for i in ['IU.wav','YU.wav','FD (1).wav','FD.wav']:
    snr(i)
# Out:
# signal to noise ratios for the file IU.wav is 0.0013439641079807398
# signal to noise ratios for the file YU.wav is 0.0007349826458836405
# signal to noise ratios for the file FD (1).wav is 0.0015611203571778756
# signal to noise ratios for the file FD.wav is 0.0015611203571778756
