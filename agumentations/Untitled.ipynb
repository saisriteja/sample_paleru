# %%
import numpy as np
def manipulate(data, noise_factor):
    noise = np.random.randn(len(data))
    augmented_data = data + noise_factor * noise
    # Cast back to same data type
    augmented_data = augmented_data.astype(type(data[0]))
    return augmented_data

# %%
import librosa
def manipulate_speed(data, speed_factor):
    return librosa.effects.time_stretch(data, speed_factor)

# %%
import librosa
def manipulate_pitch(data, sampling_rate, pitch_factor):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# %%
import os 
import IPython.display as ipd

# %%
#orginal audio
data, sr = librosa.load('audio.wav')
ipd.Audio(data,rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#speeding up the audio
speed_data = manipulate_speed(data,1.7)
ipd.Audio(speed_data, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pitch = manipulate_pitch(data,sr,3)
ipd.Audio(pitch, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
noise = manipulate(data,0.1)
ipd.Audio(noise, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pro = [0.92,2.32]  #prolongation of word name is found during this interval

# %%
ipd.Audio(data[20286:51156], rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prolonged = data[20286:51156]
fast = np.array(manipulate_speed(prolonged,3))
ipd.Audio(fast, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#perfect sentence formation
d = list(data)
perfect = d[0:20286]+list(fast)+d[51156:]
ipd.Audio(perfect, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def manipulate_mask(data,sr,arr):
    start,stop = int(arr[0]*sr),int(arr[1]*sr)
    data = list(data)
    data = data[:start]+data[stop:]
    return data
 
data, sr = librosa.load('audio.wav')    
masked = manipulate_mask(data,sr,[5.5,8])
ipd.Audio(masked, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
